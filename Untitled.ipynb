# %%
>>> import numpy as np
>>> import pandas as pd
>>> import vectorbt as vbt

>>> big_ts = pd.DataFrame(np.random.uniform(size=(1000, 1000)))

>>> %timeit big_ts.min()
>>> %timeit big_ts.vbt.tseries.min()
# Out:
# 3.94 ms ± 200 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 3.93 ms ± 235 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
>>> pd.Series([1, 2, 3]) + pd.DataFrame([[1, 2, 3]])
# Out:
#    0  1  2
# 0  2  4  6

# %%
>>> pd.Series([0.01, -0.01, 0.01]).vbt.returns(freq='1D').sharpe_ratio()
# Out:
# 5.515130702591433

# %%
>>> order_price = pd.Series([1, 2, 3, 2, 1])
>>> order_size = pd.Series([1, -1, 1, -1, 0])
>>> portfolio = vbt.Portfolio.from_orders(order_price, order_size, freq='1D')
>>> portfolio.trades.plot(width=600, height=250).show_png()

# %%
>>> print(pd.Series([1, 2, 3]) + pd.DataFrame([[1, 2, 3]]))
# Out:
#    0  1  2
# 0  2  4  6

# %%
pd.Series([2, 1, 3, 2]).vbt.tseries.drawdowns().plot(width=600, height=250).show_png()

# %%
>>> print(vbt.MA.from_params(pd.Series([1, 2, 3]), window=[2, 3], 
...      ewm=[False, True], param_product=True).ma)
# Out:
# ma_window     2               3
# ma_ewm    False     True  False     True
# 0           NaN       NaN   NaN       NaN
# 1           1.5  1.750000   NaN       NaN
# 2           2.5  2.615385   2.0  2.428571
